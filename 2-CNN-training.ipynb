# %%
import numpy as np

data=np.load('data.npy')
target=np.load('target.npy')

# %%
print(data.shape)
print(target.shape)
# Out:
# (8005, 50, 50, 1)
# (8005, 2)

# %%
print(data.shape[1:])
# Out:
# (50, 50, 1)

# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Activation,Dropout

model=Sequential()

model.add(Conv2D(128,(3,3),input_shape=data.shape[1:],padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64,(5,5)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(32,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(100,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(50,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(target.shape[1],activation='softmax'))

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)                    │ (None, 50, 50, 128)         │           1,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_6 (Activation)            │ (None, 50, 50, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 25, 25, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 21, 21, 64)          │         204,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_7 (Activation)            │ (None, 21, 21, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 10, 10, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 8, 8, 32)            │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_8 (Activation)            │ (None, 8, 8, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 4, 4, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 100)                 │          51,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 100)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 50)                  │           5,050 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 2)                   │             102 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 281,060 (1.07 MB)
#  Trainable params: 281,060 (1.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(data,target,epochs=20,validation_split=0.2,batch_size=32)
# Out:
# Epoch 1/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 43s 198ms/step - accuracy: 0.6187 - loss: 0.6692 - val_accuracy: 0.0000e+00 - val_loss: 0.9135
# Epoch 2/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 34s 167ms/step - accuracy: 0.6246 - loss: 0.6566 - val_accuracy: 0.0000e+00 - val_loss: 0.9924
# Epoch 3/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 38s 189ms/step - accuracy: 0.6246 - loss: 0.6575 - val_accuracy: 0.0000e+00 - val_loss: 0.8679
# Epoch 4/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 32s 161ms/step - accuracy: 0.6246 - loss: 0.6598 - val_accuracy: 0.0000e+00 - val_loss: 1.1384
# Epoch 5/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 34s 169ms/step - accuracy: 0.6246 - loss: 0.6585 - val_accuracy: 0.0000e+00 - val_loss: 0.9496
# Epoch 6/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 181ms/step - accuracy: 0.6245 - loss: 0.6511 - val_accuracy: 0.0000e+00 - val_loss: 0.9066
# Epoch 7/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 37s 185ms/step - accuracy: 0.6245 - loss: 0.6442 - val_accuracy: 0.0294 - val_loss: 1.1057
# Epoch 8/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 179ms/step - accuracy: 0.6280 - loss: 0.6398 - val_accuracy: 0.0162 - val_loss: 0.9000
# Epoch 9/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 38s 190ms/step - accuracy: 0.6416 - loss: 0.6318 - val_accuracy: 0.1449 - val_loss: 0.9316
# Epoch 10/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 35s 175ms/step - accuracy: 0.6557 - loss: 0.6135 - val_accuracy: 0.0981 - val_loss: 0.9643
# Epoch 11/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 39s 195ms/step - accuracy: 0.6677 - loss: 0.6054 - val_accuracy: 0.2042 - val_loss: 1.0990
# Epoch 12/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 178ms/step - accuracy: 0.6863 - loss: 0.5858 - val_accuracy: 0.3323 - val_loss: 0.8796
# Epoch 13/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 36s 176ms/step - accuracy: 0.7044 - loss: 0.5621 - val_accuracy: 0.2773 - val_loss: 1.1379
# Epoch 14/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 33s 165ms/step - accuracy: 0.7099 - loss: 0.5531 - val_accuracy: 0.5671 - val_loss: 0.7910
# Epoch 15/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 37s 184ms/step - accuracy: 0.7374 - loss: 0.5293 - val_accuracy: 0.4104 - val_loss: 0.9731
# Epoch 16/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 37s 186ms/step - accuracy: 0.7533 - loss: 0.5058 - val_accuracy: 0.5309 - val_loss: 0.9205
# Epoch 17/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 37s 184ms/step - accuracy: 0.7647 - loss: 0.4884 - val_accuracy: 0.6702 - val_loss: 0.6813
# Epoch 18/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 38s 187ms/step - accuracy: 0.7853 - loss: 0.4617 - val_accuracy: 0.6515 - val_loss: 0.7366
# Epoch 19/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 38s 187ms/step - accuracy: 0.8057 - loss: 0.4319 - val_accuracy: 0.6440 - val_loss: 0.7965
# Epoch 20/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 38s 189ms/step - accuracy: 0.8179 - loss: 0.4050 - val_accuracy: 0.5834 - val_loss: 0.8842

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['loss'],'b')
plt.plot(history.history['val_loss'],'r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 from matplotlib import pyplot as plt
# ----> 3 plt.plot(history.history['loss'],'b')
#       4 plt.plot(history.history['val_loss'],'r')
#
# NameError: name 'history' is not defined

# %%
plt.plot(history.history['acc'],'b')
plt.plot(history.history['val_acc'],'r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plt.plot(history.history['acc'],'b')
#       2 plt.plot(history.history['val_acc'],'r')
#
# NameError: name 'history' is not defined
